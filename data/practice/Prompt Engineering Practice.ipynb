# %% [markdown]
# ## 디스코드에서 공유한 `.env` 파일을 sesac-project/data/practice (지금 이 폴더)에 집어 넣기

# %%
# !source ../../.venv/bin/activate
# !pip install python-dotenv openai
# Out:
# Requirement already satisfied: python-dotenv in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: openai in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (1.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\r2com\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\r2com\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
import openai
client = OpenAI()
openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0.5):
    completion = client.chat.completions.create(
    model = model,
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=temperature
    )
    return completion.choices[0].message.content

# %% [markdown]
# ## 1. 프롬프팅의 대원칙
#
# - **원칙 1: 명확하고 구체적인 지시사항을 작성하자**
# - **원칙 2: 모델이 "생각"할 시간을 주자**
#
# - 아래 실습은 [Andrew Ng이 만든 프롬프트 수업](https://learn.deeplearning.ai/chatgpt-prompt-eng/lesson/1/introduction) 의 실습 코드를 번역한 것입니다.
#
# ### 명확하고 구체적인 지시사항을 작성하자.
#
# #### 전략 1: 입력의 구분된 부분을 명확하게 나타내기 위해 구분자 사용
#
# - 구분자는 ```, """, < >, `<tag> </tag>`, `:` 등이 될 수 있습니다.

# %%
text = f"""
모델에게 원하는 작업을 수행하도록 지시하는 것은 가능한 한 명확하고 구체적인 지시를 제공함으로써 \
이루어집니다. 이것은 모델을 원하는 출력 방향으로 이끌고, 관련 없거나 잘못된 응답을 받을 가능성을 \
줄입니다. 명확한 프롬프트 작성을 간단한 프롬프트 작성과 혼동하지 마십시오. 많은 경우, 더 긴 프롬프트는 \
모델에게 더 많은 명확성과 맥락을 제공하여 \
더 자세하고 관련 있는 출력을 이끌어낼 수 있습니다.
"""
prompt = f"""
세 개의 백틱으로 구분된 텍스트를 \
하나의 문장으로 요약하십시오.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 모델에게 명확하고 구체적인 지시를 주는 것은 중요합니다. 이렇게 함으로써 모델은 원하는 대로 작업을 수행하고 잘못된 응답을 줄일 수 있습니다. 긴 프롬프트를 사용하면 더 많은 맥락과 명확성을 제공하여 모델이 관련 있는 출력을 생성할 수 있습니다.

# %%
text = f"""
모델에게 원하는 작업을 수행하도록 지시하는 것은 가능한 한 명확하고 구체적인 지시를 제공함으로써 이루어집니다.//
이것은 모델을 원하는 출력 방향으로 이끌고, 관련 없거나 잘못된 응답을 받을 가능성을 줄입니다.//
명확한 프롬프트 작성을 간단한 프롬프트 작성과 혼동하지 마십시오.//
많은 경우, 더 긴 프롬프트는 모델에게 더 많은 명확성과 맥락을 제공하여 더 자세하고 관련 있는 출력을 이끌어낼 수 있습니다.//
"""
prompt = f"""
세 개의 백틱으로 /구분된 텍스트를 /하나의 문장으로 요약하십시오.//
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 모델에게는 명확하고 구체적인 지시를 제공하여 원하는 작업을 수행하도록 해야 합니다. 이렇게 하면 모델은 원하는 출력 방향으로 이끌리고, 잘못된 응답을 받을 가능성이 줄어듭니다. 따라서 명확한 프롬프트 작성이 중요합니다. 더 긴 프롬프트는 모델에게 더 많은 명확성과 맥락을 제공하여 더 자세하고 관련 있는 출력을 얻을 수 있습니다.

# %% [markdown]
# #### 전략 2: 구조화된 출력 요청
#
# - JSON, HTML

# %%
prompt = f"""
세 권의 가상의 책 제목과 그 저자, 장르를 생성하세요. \
book_id, title, author, genre라는 키를 포함하여 \
JSON 형식으로 제공해 주세요.

"""
response = get_completion(prompt)
print(response)
# Out:
# 다음과 같이 세 권의 가상의 책 제목과 저자, 장르를 생성할 수 있습니다.
#
# 1. book_id: 1
#    title: "프로그래밍의 기초"
#    author: "김코딩"
#    genre: "컴퓨터 과학"
#
# 2. book_id: 2
#    title: "사랑의 파도"
#    author: "박소은"
#    genre: "로맨스"
#
# 3. book_id: 3
#    title: "환상의 대륙"
#    author: "이상한 사람"
#    genre: "판타지"

# %% [markdown]
# #### 전략 3: 조건 충족 여부 확인 요청

# %%
text_1 = f"""
차를 만드는 것은 쉽습니다! 먼저, \
끓는 물을 준비해야 합니다. 그 동안, \
컵을 잡고 그 안에 차백을 넣으세요. 물이 \
충분히 뜨거워지면, 그냥 차백 위에 붓습니다. \
차가 우러나기를 잠시 기다린 후, \
몇 분 후에 차백을 꺼냅니다. 원하신다면, \
맛에 따라 설탕이나 우유를 추가할 수 있습니다. \
그게 다입니다! 맛있는 차 한 잔을 즐길 수 있습니다.
"""
prompt = f"""
세 개의 쌍따옴표로 구분된 텍스트가 제공됩니다. \
그것이 일련의 지시사항을 포함하고 있다면, \
다음 형식으로 해당 지시사항을 다시 작성하십시오:

단계 1 - ...
단계 2 - …
…
단계 N - …

텍스트에 일련의 지시사항이 포함되어 있지 않다면, \
단순히 \"단계가 제공되지 않음\"이라고 작성하십시오.

\"\"\"{text_1}\"\"\"
"""
response = get_completion(prompt)
print("Text 1에 대한 완성:")
print(response)
# Out:
# Text 1에 대한 완성:
# 단계 1 - 끓는 물을 준비합니다.
# 단계 2 - 컵을 잡고 차백을 넣습니다.
# 단계 3 - 물이 충분히 뜨거워지면, 차백 위에 붓습니다.
# 단계 4 - 차가 우러나기를 잠시 기다립니다.
# 단계 5 - 몇 분 후에 차백을 꺼냅니다.
# 단계 6 - 원하신다면, 맛에 따라 설탕이나 우유를 추가할 수 있습니다.
# 단계 7 - 맛있는 차 한 잔을 즐깁니다.

# %%
text_2 = f"""
오늘은 햇살이 밝게 빛나고, 새들이 \
노래하고 있습니다. 공원에서 산책하기에 \
아름다운 날입니다. 꽃들이 피고, 나무들이 \
산들바람에 부드럽게 흔들리고 있습니다. 사람들은 \
아름다운 날씨를 즐기기 위해 밖에 나와 있습니다. \
일부는 소풍을 즐기고, 다른 일부는 게임을 하거나 \
잔디밭에서 그냥 휴식을 취하고 있습니다. 자연의 \
아름다움을 감상하며 야외에서 시간을 보내기에 \
완벽한 날입니다.
"""
prompt = f"""
세 개의 쌍따옴표로 구분된 텍스트가 제공됩니다. \
그것이 일련의 지시사항을 포함하고 있다면, \
다음 형식으로 해당 지시사항을 다시 작성하십시오:

단계 1 - ...
단계 2 - …
…
단계 N - …

텍스트에 일련의 지시사항이 포함되어 있지 않다면, \
단순히 \"단계가 제공되지 않음\"이라고 작성하십시오.

\"\"\"{text_2}\"\"\"
"""
response = get_completion(prompt)
print("Text 2에 대한 완성:")
print(response)
# Out:
# Text 2에 대한 완성:
# 단계가 제공되지 않음

# %% [markdown]
# ## 실습하기
#
# - "뜨개질 하는 법"을 검색해서 전략 3에서 본 지시사항 다시 작성하기 테스크를 위한 프롬프트를 작성하세요.
#
# - 이 때 조건 충족여부를 체크하는 프롬프트를 꼭 포함하세요.

# %%
text_3=f"""뜨개질을 하기 위한 첫걸음은 바로 코를 뜨는 것입니다.
코를 뜨는 법은 간단하답니다. 처음에 준비한 뜨개실 한가닥으로 원을 만든 후,
원 안으로 실을 빼냅니다. 그 다음에 바늘 두개를 고리 사이로 통과시키고 실 끝을
잡아당깁니다. 여기까지 과정은 우리가 평소에 바느질할때와 비슷하니, 별로 어렵지 않으실거랍니다.
그 다음 그림 5,6,7번과 같이 손가락을 이용해 실을 고정시켜 주시고
계속해서 코를 만들어 가면 됩니다.^^
겉뜨기는 우리가 흔히 볼 수 있는 목도리 모양입니다.
심플하고 간단한 디자인의 목도리를 좋아하시는 분들에게 적합한 뜨개 방법이지요.
코를 다뜨셨다면, 이제 겉뜨기를 하실 수 있습니다.
겉뜨기는 감는 실을 반대방향으로 가도록 하여 뜨는 방식인데요.
코바늘 오른쪽을 반대쪽 아래로 꽂은 후에, 꽂은 코바늘 부분을 실로 감아주세요.
그런 후 코바늘 반대쪽 실 밑으로 빼주시고 그대로 코바늘 위로 올려주시면 됩니다.
이렇게 반복적으로 뜨다보면 심플하고 예쁜 목도리가 된답니다!
안뜨기도 우리가 흔하게 볼 수 있는 목도리, 스웨터 무늬입니다
안뜨기는 코잡기부터 시작하는데요. 실로 원을 만든 후에 원 안으로 실을 빼내고,
빼내어진 실로 만들어진 고리 안에 바늘 두개를 통과시켜서 묶어줍니다.
한손에는 바늘을 잡고 한손에는 실자락을 잡은 후 순서대로 실을 겁니다.
편물의 크기에 따라서 코의 개수를 정하면 원하는 크기대로 목도리를 만들 수 있답니다.^^
고무뜨기는 겉뜨기와 안뜨기를 규칙적으로 혼합한 뜨개 방식입니다.
신축성이 있기 때문에 고무뜨기라고 하는데요. 고무뜨기는 신축성이 있기 때문에
소매, 목둘레, 앞단, 아랫단, 주머닛단에 많이 사용되는 방법이라고 합니다.
고무뜨기는 겉뜨기, 안뜨기를 규칙적으로 연속해서 뜨는 콧수에 의해 정해진다고 합니다.
1코 고무뜨기는 겉뜨기 1코, 안뜨기 1코이고
2코 고무뜨기는 겉뜨기 2코, 안뜨기 2코로 뜨는 것입니다.
2코 고무뜨기는 1코 고무뜨기 과정 2번에서 코만 2개 잡아주시면 된답니다.
가터뜨기는 평뜨기와 둥근뜨기를 동시에 하여 만드는 방법입니다.
평뜨기는 1단마다 겉뜨기, 둥근뜨기는 1단마다 겉뜨기와 안뜨기를 하면 되는데요.
겉코와 안코가 나오게 되는 요철모양의 뜨개방법입니다. 그렇기 때문에
상하로는 늘어나지만 좌우로는 신축이 안되고 바탕은 두껍습니다.
가터뜨기는 굵은 바늘을 사용하며 반대로 코와 코 사이가 느슨해서 공간이 생길때는
가는 바늘을 사용하면 됩니다.
목도리, 스웨터를 방법대로 잘 뜨셨다면 마무리를 잘 해야겠지요?
마지막으로 코막기를 잘 해야합니다. 코막기는 첫번째, 두번째 뜨기를 안뜨기로 하고
첫번째 코를 두번째 코 위로 덮어씌우면 된답니다. 이 과정을 계속 반복하고
마지막 코는 코 사이로 실을 빼내어 매듭만 단단히 지어주면 됩니다.
뜨개질 하는 방법, 이렇게 보니까 정말 쉽지요?
뜨개질은 처음엔 어려울 수 있지만 계속 반복하다보면 어느샌가 손에 익어서
잘 할 수 있을거랍니다! 올 겨울엔 정성 가득 들어간 목도리 선물해보세요~
(출처 : 두산백과)
"""
prompt=f"""세 개의 쌍따옴표로 구분된 텍스트를 제공할건데순서대로 요약해줘 순서가 없으면 그냥 'x' 라고 반환해주면 돼
요약할때 주의사항이 있는데 형식은 다음과 같아:
단계 1 - ...
단계 2 - …
 …
단계 N - …
\"\"\"{text_3}\"\"\"
"""

response = get_completion(prompt)
print("실습에 대한 완성:")
print(response)
# Out:
# 실습에 대한 완성:
# 단계 1 - 코를 뜨는 방법을 설명한다.
# 단계 2 - 겉뜨기를 하는 방법을 설명한다.
# 단계 3 - 안뜨기를 하는 방법을 설명한다.
# 단계 4 - 고무뜨기를 하는 방법을 설명한다.
# 단계 5 - 가터뜨기를 하는 방법을 설명한다.
# 단계 6 - 마무리하는 방법을 설명한다.

# %% [markdown]
# #### 전략 4: "Few-shot" 프롬프팅

# %%
prompt = f"""
일관된 스타일로 답변하는 것이 과제입니다.

<아이>: 인내에 대해 가르쳐 주세요.

<할머니/할아버지>: 가장 깊은 계곡을 파는 강은 \
겸손한 봄에서 흐릅니다; 가장 웅장한 교향곡은 \
하나의 단일한 음에서 시작됩니다; 가장 복잡한 태피스트리는 \
단 하나의 실로부터 시작됩니다.

<아이>: 회복력에 대해 가르쳐 주세요.
"""
response = get_completion(prompt)
print(response)
# Out:
# <할머니/할아버지>: 나무가 바람에 휘날리면서도 다시 일어서는 것처럼, 삶에서 어려움을 겪더라도 다시 일어날 수 있는 힘을 갖추어야 합니다. 어떤 상황에서도 희망을 잃지 말고, 자신을 다시 일으킬 수 있는 능력을 기르는 것이 중요합니다.

# %% [markdown]
# ### 원칙 2: 모델에게 "생각"할 시간을 주자
#
# #### 전략 1: 작업을 완료하기 위해 필요한 단계 명시

# %%
text = f"""
매력적인 마을에서, 잭과 질이라는 형제는 \
언덕 꼭대기에 있는 우물에서 물을 길으러 가는 \
모험을 떠납니다. 그들이 즐겁게 노래를 부르며 올라가던 중, \
불행이 닥쳤습니다—잭이 돌에 걸려 넘어져 \
언덕 아래로 굴러떨어졌고, 질도 뒤따라 넘어졌습니다. \
약간 다쳤지만, 그들은 위로하는 포옹 속으로 \
집으로 돌아왔습니다. 사건에도 불구하고, \
그들의 모험심은 여전히 빛났고, 그들은 기쁨으로 계속 탐험을 이어갔습니다.
"""
# 예시 1
prompt_1 = f"""
다음 작업을 수행하십시오:
1 - 세 개의 백틱(```)으로 구분된 다음 텍스트를 한 문장으로 요약합니다.
2 - 요약문을 프랑스어로 번역합니다.
3 - 프랑스어 요약문에 있는 각 이름을 나열합니다.
4 - 다음 키를 포함하는 json 객체를 출력합니다: french_summary, num_names.

각 답변을 줄바꿈으로 구분하십시오.

텍스트:
```{text}```
"""
response = get_completion(prompt_1)
print("prompt 1에 대한 완성:")
print(response)
# Out:
# prompt 1에 대한 완성:
# 매력적인 마을에서, 잭과 질이라는 형제는 우물에서 물 길으러 가는 모험을 떠납니다.

# %% [markdown]
# #### 지정된 형식으로 출력 요청

# %%
prompt_2 = f"""
다음 작업을 수행하는 것이 과제입니다:
1 - <>로 구분된 다음 텍스트를 한 문장으로 요약합니다.
2 - 요약문을 프랑스어로 번역합니다.
3 - 프랑스어 요약문에 있는 각 이름을 나열합니다.
4 - 다음 키를 포함하는 json 객체를 출력합니다: french_summary, num_names.

다음 형식을 사용하십시오:
텍스트: <요약할 텍스트>
요약: <요약문>
번역: <요약문 번역>
이름: <요약문 내 이름 목록>
JSON 출력: <요약과 num_names가 있는 json>

텍스트: <{text}>
"""
response = get_completion(prompt_2)
print("\nprompt 2에 대한 완성:")
print(response)
# Out:
# prompt 2에 대한 완성:
# 요약: 잭과 질은 우물에서 물을 길으러 가는 모험을 떠납니다. 잭이 넘어져 굴러떨어지고, 질도 뒤따라 넘어지지만 그들은 포옹하며 집으로 돌아옵니다. 그들은 여전히 모험심이 빛나며 탐험을 이어갑니다.
# 번역: Dans un charmant village, les frères Jack et Jill partent à l'aventure pour puiser de l'eau dans un puits au sommet d'une colline. Alors qu'ils montent en chantant joyeusement, un malheur survient - Jack trébuche sur une pierre et tombe en bas de la colline, suivi de Jill. Bien qu'ils soient légèrement blessés, ils se réconfortent mutuellement et retournent chez eux. Malgré cet incident, leur esprit d'aventure brille toujours et ils continuent d'explorer avec joie.
# 이름: Jack, Jill
# JSON 출력: {"french_summary": "Dans un charmant village, les frères Jack et Jill partent à l'aventure pour puiser de l'eau dans un puits au sommet d'une colline. Alors qu'ils montent en chantant joyeusement, un malheur survient - Jack trébuche sur une pierre et tombe en bas de la colline, suivi de Jill. Bien qu'ils soient légèrement blessés, ils se réconfortent mutuellement et retournent chez eux. Malgré cet incident, leur esprit d'aventure brille toujours et ils continuent d'explorer avec joie.", "num_names": 2}

# %% [markdown]
# #### 전략 2: 모델이 결론을 서둘러서 도달하기 전에 자체 해결책을 찾도록 지시한다.

# %%
prompt = f"""
학생의 해결책이 올바른지 아닌지 판단하십시오.

질문:
저는 태양광 발전 설치를 구축하고 있고, 재정 계산에 \
도움이 필요합니다.
- 땅은 평방 피트당 $100입니다.
- 태양광 패널을 평방 피트당 $250에 구입할 수 있습니다.
- 저는 유지보수에 대한 계약을 협상하여 연간 고정 $100k, \
추가로 평방 피트당 $10의 비용이 듭니다.
제곱피트 수에 따른 첫 해 운영 총비용은 얼마입니까?

학생의 해결책:
설치 크기를 평방 피트 단위의 x라고 합시다.
비용:
1. 땅 비용: 100x
2. 태양광 패널 비용: 250x
3. 유지보수 비용: 100,000 + 100x
총비용: 100x + 250x + 100,000 + 100x = 450x + 100,000
"""
response = get_completion(prompt)
print(response)
# Out:
# 학생의 해결책은 올바릅니다. 총비용은 설치 크기를 평방 피트 단위로 나타낸 x에 대한 식으로 표현되었습니다. 땅 비용, 태양광 패널 비용, 유지보수 비용을 모두 고려하여 총비용을 계산하였습니다. 따라서 학생의 해결책은 올바른 해결책입니다.

# %% [markdown]
# #### 실제로 학생의 해결책은 올바르지 않다.
#
# #### 모델에게 먼저 자체 해결책을 작업하도록 지시함으로써 이를 수정할 수 있습니다.

# %%
prompt = f"""
학생의 해결책이 올바른지 아닌지 판단하는 것이 과제입니다.
문제를 해결하기 위해 다음을 수행하십시오:
- 먼저, 문제에 대한 자신만의 해결책을 포함하여 최종 총계를 계산합니다.
- 그런 다음 학생의 해결책과 비교하여 학생의 해결책이 올바른지 평가합니다.
문제를 스스로 풀어보기 전까지 학생의 해결책이 올바른지 결정하지 마십시오.

다음 형식을 사용하십시오:
질문:
```
여기에 질문
```
학생의 해결책:
```
여기에 학생의 해결책 
```
실제 해결책:
```
여기에 해결책을 작업하는 단계와 당신의 해결책 
```
학생의 해결책이 방금 계산한 실제 해결책과 같은지:
```
예 또는 아니오
```
학생 성적:
```
정확함 또는 부정확함
```
질문:
```
태양광 발전 설치를 구축하고 있으며 재정적 계산에 도움이 필요합니다.
- 땅은 평방 피트당 $100입니다.
- 태양광 패널은 평방 피트당 $250에 구입할 수 있습니다.
- 유지보수 계약을 체결하여 연간 고정 $100k의 비용이 들며, 추가로 평방 피트당 $10이 추가됩니다.
제곱피트 수에 따른 첫 해 운영 총비용은 얼마입니까?
```
학생의 해결책:
```
설치 크기를 평방 피트 단위의 x라고 합시다.
비용:
1. 땅 비용: 100x
2. 태양광 패널 비용: 250x
3. 유지보수 비용: 100,000 + 100x
총비용: 100x + 250x + 100,000 + 100x = 450x + 100,000
```
실제 해결책:
"""
response = get_completion(prompt)
print(response)
# Out:
# ```
# 설치 크기를 평방 피트 단위의 x라고 합시다.
# 비용:
# 1. 땅 비용: 100x
# 2. 태양광 패널 비용: 250x
# 3. 유지보수 비용: (100,000 + 10x) * x
# 총비용: 100x + 250x + (100,000 + 10x) * x
# ```
# 학생의 해결책이 방금 계산한 실제 해결책과 같은지:
# ```
# 아니오
# ```
# 학생 성적:
# ```
# 부정확함
# ```

# %% [markdown]
# ## 모델의 한계: 환각
#
# - Boie는 실제 회사이지만, 제품명은 실제가 아닙니다.

# %%
prompt = f"""
Boie의 AeroGlide UltraSlim Smart Toothbrush에 대해 알려주세요.
"""
response = get_completion(prompt)
print(response)
# Out:
# Boie의 AeroGlide UltraSlim Smart Toothbrush는 혁신적인 스마트 치약입니다. 이 제품은 높은 품질의 소프트 브리슬과 고급 나일론 소재로 만들어져 있으며, 치아와 잇몸을 부드럽게 깨끗하게 해줍니다.
#
# AeroGlide UltraSlim Smart Toothbrush는 똑똑한 기능을 갖추고 있어 칫솔질을 효과적으로 도와줍니다. 이 제품은 블루투스 기술을 사용하여 스마트폰과 연결되며, 사용자의 칫솔질 습관을 기록하고 개선할 수 있습니다. 앱을 통해 칫솔질 시간, 압력, 움직임 등의 데이터를 추적할 수 있어 개인의 치아 건강을 관리하는 데 도움이 됩니다.
#
# 또한, AeroGlide UltraSlim Smart Toothbrush는 3D 소닉 기술을 사용하여 최대 40,000회의 브러시 스트로크를 제공합니다. 이는 치아와 잇몸 사이의 치석과 이물질을 효과적으로 제거하고 치아를 깨끗하게 유지하는 데 도움이 됩니다.
#
# 이 제품은 USB 충전식이며, 충전 한 번으로 최대 30일 동안 사용할 수 있습니다. 또한, 슬림하고 경량 디자인으로 휴대하기 편리하며, 충전이 필요한 경우에는 앱을 통해 알림을 받을 수 있습니다.
#
# AeroGlide UltraSlim Smart Toothbrush는 혁신적인 기능과 높은 품질로 사용자에게 편리하고 효과적인 칫솔질 경험을 제공합니다.

# %% [markdown]
# ## 실습: 환각 문제를 해결하기 위해 어떻게 해야 할까요? 프롬프트로 작성해 보세요.

# %%
# YOUR CODE HERE.

prompt = f"""
고종의 맥북 도난 사건에 대해 알려줘.

"""
response = get_completion(prompt)
print(response)
# Out:
# 고종의 맥북 도난 사건은 2021년 10월 21일에 발생한 사건으로, 대한민국의 가수 고종이 자신의 맥북 프로를 도난당한 사건을 의미합니다. 이 사건은 고종이 자신의 소셜 미디어 계정을 통해 공개적으로 알리면서 큰 관심을 받았습니다.
#
# 고종은 사건 발생 당시 자신의 맥북 프로가 자신의 차량에서 도난당한 것을 발견하였고, 이에 대해 사진과 함께 자신의 트위터 계정을 통해 "맥북 프로가 도난당했다"고 밝혔습니다. 이 글은 빠르게 확산되어 수많은 팬들과 미디어의 주목을 받았으며, 많은 사람들이 도난에 대한 안타까움과 공감을 표하였습니다.
#
# 이후, 고종은 경찰에 도난 사건을 신고하였으며, 경찰은 CCTV 영상 등을 통해 범인을 추적하고자 노력하였습니다. 또한, 고종은 맥북의 시리얼 넘버와 기타 정보를 공유하여 도난된 맥북이 판매되거나 거래되는 것을 방지하기 위한 노력을 기울였습니다.
#
# 이 사건은 고종의 소개하는 맥북 프로의 특징과 가치에 대한 관심을 높였으며, 또한 도난에 대한 경각심을 일깨웠습니다. 고종은 팬들과 함께 사건 해결을 위해 노력하고 있으며, 맥북의 도난 사건은 많은 사람들에게 경각심을 주는 계기가 되었습니다.

# %%
# YOUR CODE HERE.

prompt = f"""
정보를 찾아보고 없으면 그냥 없다 라고 적어줘
임진왜란에 대해 알려줘
"""
response = get_completion(prompt)
print(response)
# Out:
# 임진왜란은 1592년부터 1598년까지 일본의 토요타이씨(豊臣秀吉)가 조선을 침공한 전쟁입니다. 일본은 조선을 정복하여 중국에 대한 침공의 발판으로 삼으려는 목적으로 침공을 시작했습니다. 이 전쟁은 일본의 초비국정(鳥瞰國情)과 조선의 명나라에 대한 도움 요청으로 인해 발발하게 되었습니다. 임진왜란은 세 번의 침공과 세 번의 조선의 저항으로 이루어져 있으며, 조선의 임진왜란 저항은 군사적, 정치적, 외교적인 측면에서 큰 영향을 미쳤습니다. 이 전쟁은 일본의 실패로 끝나게 되었으며, 이후로 조선은 외국 침략에 대한 방어 체계를 강화하였습니다.

# %% [markdown]
# #### 백슬래시에 대한 참고사항
#
# - 이 과정에서는 텍스트가 화면에 맞게 표시되도록 하기 위해 백슬래시 `\`를 사용하고 있습니다. 이는 새 줄 '\n' 문자를 삽입하지 않기 위함입니다.
# - GPT-3는 실제로 줄바꿈 문자를 삽입하든 말든 크게 영향을 받지 않습니다. 하지만 일반적으로 LLM을 사용할 때 프롬프트의 줄바꿈 문자가 모델의 성능에 영향을 미칠 수 있습니다.

# %% [markdown]
# ## 2. 반복적 프롬프트 작성
#
# ## 마케팅 제품 설명 생성하기: 제품 사양서를 기반으로

# %%
fact_sheet_chair = """
개요
- 중세 현대적인 사무용 가구의 아름다운 가족 중 하나로,
  파일 캐비닛, 책상, 책장, 회의용 테이블 등이 포함됩니다.
- 쉘 색상과 베이스 마감 옵션이 다양합니다.
- 플라스틱 뒷면과 앞면의 패브릭 장식이 있는 옵션(SWC-100)과
  10가지 패브릭 및 6가지 가죽 옵션이 있는 전체 장식 옵션(SWC-110)이 있습니다.
- 베이스 마감 옵션에는 스테인리스 스틸, 매트 블랙,
  광택 화이트, 크롬이 있습니다.
- 의자는 팔걸이가 있는 버전과 없는 버전이 있습니다.
- 가정이나 사업장에 적합합니다.
- 계약용으로 인증되었습니다.

구조
- 5개 바퀴가 있는 플라스틱 코팅 알루미늄 베이스.
- 손쉬운 상하 조정을 위한 공압 의자 조절 기능.

치수
- 폭 53 CM | 20.87”
- 깊이 51 CM | 20.08”
- 높이 80 CM | 31.50”
- 좌석 높이 44 CM | 17.32”
- 좌석 깊이 41 CM | 16.14”

옵션
- 부드러운 바닥 또는 단단한 바닥 캐스터 옵션.
- 좌석 폼 밀도 두 가지 선택:
  중간 (1.8 lb/ft3) 또는 높음 (2.8 lb/ft3)
- 팔걸이 없거나 8가지 위치 조정이 가능한 PU 팔걸이

재료
쉘 베이스 글라이더
- 수정된 나일론 PA6/PA66 코팅이 있는 주조 알루미늄.
- 쉘 두께: 10 mm.
좌석
- HD36 폼

제조국
- 이탈리아
"""
prompt = f"""
마케팅 팀을 도와 기술 사양서를 기반으로 소매 웹사이트에 대한 제품 설명을 만듭니다.

세 개의 백틱으로 구분된 기술 사양에 제공된 정보를 기반으로 제품 설명을 작성하세요.

기술 사양: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 저희의 중세 현대적인 사무용 가구는 아름다운 가족 중 하나로, 파일 캐비닛, 책상, 책장, 회의용 테이블 등을 포함하고 있습니다. 이 제품은 다양한 쉘 색상과 베이스 마감 옵션을 제공합니다. 또한, 플라스틱 뒷면과 앞면에 패브릭 장식이 있는 옵션(SWC-100)과 전체적으로 패브릭 및 가죽 옵션이 있는 전체 장식 옵션(SWC-110)이 있습니다. 베이스 마감 옵션으로는 스테인리스 스틸, 매트 블랙, 광택 화이트, 크롬이 있습니다.
#
# 이 제품은 팔걸이가 있는 버전과 없는 버전의 의자가 있어서 다양한 사용자의 요구에 맞게 선택할 수 있습니다. 또한, 가정이나 사업장에 적합하며, 계약용으로 인증되었습니다.
#
# 구조적으로는 5개 바퀴가 있는 플라스틱 코팅 알루미늄 베이스를 사용하고 있으며, 공압 의자 조절 기능을 통해 손쉽게 상하 조정이 가능합니다.
#
# 이 제품의 치수는 폭 53 CM, 깊이 51 CM, 높이 80 CM, 좌석 높이 44 CM, 좌석 깊이 41 CM입니다.
#
# 옵션으로는 부드러운 바닥 또는 단단한 바닥 캐스터 옵션이 있으며, 좌석 폼 밀도는 중간 (1.8 lb/ft3) 또는 높음 (2.8 lb/ft3)을 선택할 수 있습니다. 또한, 팔걸이 없거나 8가지 위치 조정이 가능한 PU 팔걸이도 제공됩니다.
#
# 이 제품은 수정된 나일론 PA6/PA66 코팅이 있는 주조 알루미늄으로 제작된 쉘 베이스 글라이더를 사용하고 있으며, 쉘의 두께는 10 mm입니다. 좌석은 HD36 폼으로 만들어졌으며, 이 제품의 제조국은 이탈리아입니다.

# %% [markdown]
# ## 문제 1: 텍스트가 너무 길다
#
# - 단어/문장/문자 수를 제한하세요.

# %%
prompt = f"""
마케팅 팀을 도와 기술 사양서를 기반으로 소매 웹사이트에 대한 제품 설명을 만듭니다.

세 개의 백틱으로 구분된 기술 사양에 제공된 정보를 기반으로 제품 설명을 작성하세요.


기술 사양: ```{fact_sheet_chair}```

-------
최대 50단어를 사용하세요.

"""
response = get_completion(prompt)
print(response)
# Out:
# 이 중세 현대적인 사무용 가구는 파일 캐비닛, 책상, 책장, 회의용 테이블 등을 포함하고 있습니다. 다양한 쉘 색상과 베이스 마감 옵션으로 제공되며, 패브릭 또는 가죽 장식이 있는 옵션도 있습니다. 플라스틱 코팅 알루미늄 베이스에는 5개의 바퀴가 있으며, 공압 의자 조절 기능으로 상하 조정이 가능합니다. 이 제품은 가정이나 사업장에 적합하며, 계약용으로 인증되었습니다.

# %%
len(response.split())
# Out:
# 49

# %% [markdown]
# ## 문제 2. 텍스트가 잘못된 세부사항에 초점을 맞춤
#
# - 의도한 대상에게 관련 있는 측면에 초점을 맞추도록 요청합니다.

# %%
prompt = f"""
마케팅 팀을 도와 기술 사양서를 기반으로 소매 웹사이트에 대한 제품 설명을 만듭니다.

세 개의 백틱으로 구분된 기술 사양에 제공된 정보를 기반으로 제품 설명을 작성하세요.

이 설명은 가구 소매업체를 대상으로 하므로, 기술적 성격을 띄어야 하며 제품이 구성된 재료에 초점을 맞춰야 합니다.

최대 50단어를 사용하세요.

기술 사양: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)

# %%
prompt = f"""
마케팅 팀을 도와 기술 사양서를 기반으로 소매 웹사이트에 대한 제품 설명을 만듭니다.

세 개의 백틱으로 구분된 기술 사양에 제공된 정보를 기반으로 제품 설명을 작성하세요.

이 설명은 가구 소매업체를 대상으로 하므로, 기술적 성격을 띄어야 하며 제품이 구성된 재료에 초점을 맞춰야 합니다.

설명의 마지막에 기술 사양에서 모든 7자리 제품 ID를 포함하세요.

최대 50단어를 사용하세요.

기술 사양: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 우리의 중세 현대적인 사무용 가구 시리즈는 파일 캐비닛, 책상, 책장, 회의용 테이블 등 다양한 제품으로 구성되어 있습니다. 다양한 쉘 색상과 베이스 마감 옵션을 선택할 수 있습니다. 제품에는 플라스틱 뒷면과 앞면의 패브릭 장식이 있는 SWC-100 옵션과 10가지 패브릭 및 6가지 가죽 옵션이 있는 SWC-110 옵션이 있습니다. 베이스 마감 옵션으로는 스테인리스 스틸, 매트 블랙, 광택 화이트, 크롬이 있습니다. 의자에는 팔걸이가 있는 버전과 없는 버전이 있습니다. 이 제품은 가정이나 사업장에 적합하며 계약용으로 인증되었습니다. 제품 ID: SWC-100, SWC-110. (50 words)

# %% [markdown]
# ## 문제 3. 설명에 치수 표가 필요

# %%
prompt = f"""
마케팅 팀을 도와 기술 사양서를 기반으로 소매 웹사이트에 대한 제품 설명을 만듭니다.

세 개의 백틱으로 구분된 기술 사양에 제공된 정보를 기반으로 제품 설명을 작성하세요.

이 설명은 가구 소매업체를 대상으로 하므로, 기술적 성격을 띄어야 하며 제품이 구성된 재료에 초점을 맞춰야 합니다.

설명의 마지막에 기술 사양에서 모든 7자리 제품 ID를 포함하세요.

설명 후에 제품의 치수를 나타내는 표를 포함하세요. 표에는 두 개의 열이 있어야 합니다.
첫 번째 열에는 치수의 이름을 포함시키고, 두 번째 열에는 인치 단위로 측정값을 포함시키세요.

표에 'Product Dimensions'라는 제목을 부여하세요.

모든 것을 웹사이트에서 사용할 수 있는 HTML 형식으로 작성하세요.
설명을 <div> 요소 안에 배치하세요.

기술 사양: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <div>
#   <p>
#     중세 현대적인 사무용 가구의 아름다운 가족 중 하나로, 파일 캐비닛, 책상, 책장, 회의용 테이블 등이 포함됩니다. 이 제품은 가구 소매업체를 대상으로 하며, 기술적인 성격을 띄고 있으며 제품이 구성된 재료에 초점을 맞추고 있습니다.
#   </p>
#   <p>
#     이 제품은 다양한 쉘 색상과 베이스 마감 옵션을 제공합니다. 옵션 중에는 플라스틱 뒷면과 앞면의 패브릭 장식이 있는 SWC-100과 전체 장식 옵션인 SWC-110이 있습니다. 전체 장식 옵션은 10가지 패브릭 및 6가지 가죽 옵션을 제공합니다. 또한, 베이스 마감 옵션으로 스테인리스 스틸, 매트 블랙, 광택 화이트, 크롬이 있습니다.
#   </p>
#   <p>
#     이 제품은 팔걸이가 있는 버전과 없는 버전의 의자를 제공합니다. 또한, 가정이나 사업장에 적합하며 계약용으로 인증되었습니다.
#   </p>
#   <p>
#     구조적으로는 5개 바퀴가 있는 플라스틱 코팅 알루미늄 베이스와 손쉬운 상하 조정을 위한 공압 의자 조절 기능을 가지고 있습니다.
#   </p>
#   <h3>제품 치수</h3>
#   <table>
#     <tr>
#       <th>치수</th>
#       <th>인치</th>
#     </tr>
#     <tr>
#       <td>폭</td>
#       <td>20.87"</td>
#     </tr>
#     <tr>
#       <td>깊이</td>
#       <td>20.08"</td>
#     </tr>
#     <tr>
#       <td>높이</td>
#       <td>31.50"</td>
#     </tr>
#     <tr>
#       <td>좌석 높이</td>
#       <td>17.32"</td>
#     </tr>
#     <tr>
#       <td>좌석 깊이</td>
#       <td>16.14"</td>
#     </tr>
#   </table>
#   <p>
#     이 제품은 부드러운 바닥 또는 단단한 바닥 캐스터 옵션을 제공합니다. 또한, 좌석 폼 밀도는 중간 (1.8 lb/ft3) 또는 높음 (2.8 lb/ft3) 중에서 선택할 수 있습니다. PU 팔걸이는 팔걸이 없는 옵션과 8가지 위치 조정이 가능한 옵션 중에서 선택할 수 있습니다.
#   </p>
#   <p>
#     이 제품은 쉘 베이스 글라이더로 수정된 나일론 PA6/PA66 코팅이 있는 주조 알루미늄을 사용하고 있습니다. 쉘의 두께는 10 mm입니다. 좌석은 HD36 폼으로 만들어졌습니다.
#   </p>
#   <p>
#     이 제품은 이탈리아에서 제조되었습니다.
#   </p>
#   <p>
#     기술 사양에서 제공된 모든 7자리 제품 ID는 다음과 같습니다: [제품 ID를 여기에 입력하세요].
#   </p>
# </div>

# %% [markdown]
# #### (참고) HTML 볼 수 있는 라이브러리

# %%
from IPython.display import display, HTML
display(HTML(response))

# %% [markdown]
# ## 3. 문서 요약하기

# %%
prod_review = """
내 딸의 생일 선물로 이 판다 인형을 받았습니다. \
내 딸은 이 인형을 사랑하고 어디든지 가지고 다닙니다. \
부드럽고 귀여운데, 얼굴이 친근한 느낌입니다. 하지만 \
내가 지불한 가격에 비해 조금 작아 보입니다. \
같은 가격으로 더 큰 옵션이 있을 것 같아요. 예상보다 \
하루 일찍 도착해서 딸에게 주기 전에 스스로 먼저 놀 수 있었습니다.
"""

# %% [markdown]
# ## 단어, 문장, 글자수 제한을 두고 요약하기

# %%
prompt = f"""
제공한 e-commerce 사이트의 제품 리뷰를 간단하게 요약하는 것이 \
당신의 과제입니다.

다음의 리뷰를, 삼중 역따옴표로 묶인 부분을 기준으로, \


리뷰: ```{prod_review}```


최대 30단어로 요약해보세요.
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### "배송 및 납품"에 중점을 둔 요약

# %%
prompt = f"""
배송 부서에 피드백을 제공하기 위해 e-commerce 사이트의 제품 리뷰를 간단하게 요약하는 것이 \
당신의 과제입니다.

다음의 리뷰를, 삼중 역따옴표로 묶인 부분을 기준으로, \

리뷰: ```{prod_review}```
잊지마. 최대 30단어로 요약하되, 제품의 배송 및 납품에 관한 어떤 측면을 언급하는지에 중점을 두세요.

"""

response = get_completion(prompt)
print(response)
# Out:
# 이 판다 인형은 딸의 생일 선물로 받았는데, 딸이 너무 좋아하고 어디든지 가지고 다니기 편해요. 하지만 가격에 비해 조금 작아 보이고, 더 큰 옵션이 있었으면 좋겠어요. 배송은 예상보다 일찍 도착해서 딸이 먼저 놀 수 있었어요.

# %% [markdown]
# ### "가격 및 가치"에 중점을 둔 요약

# %%
prompt = f"""
제품의 가격을 결정하는 가격 부서에 피드백을 제공하기 위해 e-commerce 사이트의 제품 리뷰를 간단하게 요약하는 것이 \
당신의 과제입니다.

다음의 리뷰를, 삼중 역따옴표로 묶인 부분을 기준으로, \
최대 30단어로 요약하되, 제품의 가격 및 인식된 가치와 관련된 어떤 측면에 중점을 두세요.

리뷰: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### 주의:
#
# - 요약은 주어진 리뷰에서 해당 주제에 중점을 두지만, 다른 주제와 관련된 내용도 일부 포함할 수 있습니다.

# %% [markdown]
# ## 요약("summarize") 대신에 추출("extract")을 시도해보자.
#
# ## 배송 및 납품과 관련된 정보를 추출

# %%
prompt = f"""
배송 부서에 피드백을 제공하기 위해 e-commerce 사이트의 제품 리뷰에서 \
배송 및 납품과 관련된 정보를 추출하는 것이 당신의 과제입니다.

삼중 역따옴표로 묶인 부분에서 배송 및 납품과 관련된 정보를 추출하되, \
최대 30단어로 제한하세요.

리뷰: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)
# Out:
# 배송 및 납품과 관련된 정보: "하루 일찍 도착"

# %% [markdown]
# ### 여러 제품 리뷰 요약

# %%
review_1 = prod_review

# 무선 램프에 대한 리뷰
review_2 = """
침실용으로 좋은 램프가 필요했는데, 이 제품은 추가 저장 공간이 있고 가격도 \
높지 않아 선택했습니다. 빠르게 받았습니다 - 2일 내에 도착했습니다. \
램프의 스트링이 운송 중에 끊어졌고 회사는 기꺼이 새로운 것을 보내주었습니다. \
새로운 것 역시 몇 일 안에 도착했습니다. 램프 조립은 쉬웠습니다. 그런 다음 \
부품이 누락되었는데, 지원팀에 연락하니 빠르게 누락된 부분을 받았습니다! \
이 회사는 고객과 제품에 관심을 가지는 것 같습니다.
"""
# 전기 칫솔에 대한 리뷰
review_3 = """
내 치과 위생사는 전기 칫솔을 추천했기 때문에 이것을 구입했습니다. \
배터리 수명은 현재로서는 꽤 훌륭한 것 같습니다. 초기 충전 후에 \
배터리를 형성하기 위해 첫 주에 충전기를 연결한 후, 마지막 3주 동안 \
똑같은 충전으로 매일 두 번 브러싱했습니다. 그러나 칫솔 머리가 너무 작습니다. \
이 머리보다 큰 아기 칫솔을 본 적이 있습니다. 이 머리가 이를 통해 치아 사이에 \
더 잘 들어가게 하려면 다른 길이의 솔로 필요합니다. 전체적으로 $50 정도에 \
구할 수 있다면 좋은 거래입니다. 제조사의 교체 헤드는 꽤 비싸지만, \
더 합리적인 가격에 제공되는 일반 헤드를 구할 수 있습니다. 이 칫솔은 매일 \
치과의사에 다녀온 것 같은 느낌을 줍니다. 내 이가 반짝반짝합니다!
"""
# 믹서기에 대한 리뷰
review_4 = """
11월에 17개 조각 시스템을 약 $49에 구매할 수 있었지만, 12월의 두 번째 주에 \
동일한 시스템에 대한 가격이 (가격 인상이라고 부르겠습니다) 어떤 이유로든 $70-$89 \
사이로 상승했습니다. 그리고 11개 조각 시스템도 이전에 $29에 판매된 가격보다 \
약 $10 정도 오른 가격이었습니다. 따라보면 괜찮아 보이지만, 베이스를 보면 블레이드가 \
이전 버전에서 좋아 보이지 않습니다. 하지만 나는 이를 매우 조심스럽게 다루기 \
계획이다 (예: 빈, 얼음, 쌀 등을 블렌더에서 깨끗하게 분쇄한 다음 블렌더에서 \
원하는 서빙 사이즈로 분쇄하기 위해 처음에는 블렌더에서 크러싱, \
스무디를 만들 때 처음에 교차 컷팅 블레이드를 사용한 다음 필요하면 \
더 가는/적게 과립화된 서브 프로세서를 사용한 다음 교차 컷팅 블레이드를 \
사용하십시오. 스무디를 만들 때 팁: 과일과 야채를 미세하게 썰고 얼려두세요 \
(시금치를 사용한다면 시금치를 가볍게 데쳐서 사용할 때까지 얼려두세요 - \
소프트하게 데치면 얼려둔 다음 사용할 준비가 될 때까지, \
소르베를 만들 때 소형 또는 중형 식품 프로세서 사용) - \
이렇게 하면 스무디를 만들 때 얼음을 그다지 많이 추가하지 않아도 됩니다. \
약 1년 후에 모터가 이상한 소리를 내기 시작했습니다. 고객 서비스에 전화했지만 \
보증이 이미 만료되었으므로 새로 사야 했습니다. 참고로 이러한 제품 유형의 \
전반적인 품질이 저하되었으므로 이러한 제품의 판매를 유지하기 위해 브랜드 인식 \
및 소비자 충성도를 양산하고 있습니다. 약 2일 안에 받았습니다.
"""

# %%
reviews = [review_1, review_2, review_3, review_4]

# %%
for i in range(len(reviews)):
    prompt = f"""
    e-commerce 사이트의 제품 리뷰를 간단하게 요약하는 것이 \
    당신의 과제입니다.

   
    리뷰: ```{reviews[i]}```
    
    삼중 역따옴표로 묶인 부분을 기준으로, 최대 20단어로 요약하세요.

    """

    response = get_completion(prompt)
    print(i, response, "\n")

# %% [markdown]
# ## 3. 추론하기
#
# - 제품 리뷰와 뉴스 기사에서 감정과 주제를 추론

# %% [markdown]
# ## 제품 리뷰 텍스트

# %%
lamp_review = """
내 침실을 위한 좋은 램프가 필요했는데, 이 제품은 추가 저장 공간이 있고 가격도 \
너무 높지 않았습니다. 빨리 받았습니다. 램프 스트링이 운송 중에 끊어졌고 \
회사는 기꺼이 새로운 것을 보내주었습니다. 몇 일 안에 도착했습니다. \
조립은 쉬웠습니다. 부품이 누락되었는데, 지원팀에 연락하여 \
빠르게 누락 부분을 받았습니다! Lumina는 고객과 제품에 관심을 가지는 \
훌륭한 회사로 보입니다!!
"""

# %% [markdown]
# ## 감정 (긍정적/부정적)

# %%
prompt = f"""
다음 제품 리뷰의 감정은 무엇인가요?
삼중 역따옴표로 구분된 다음 제품 리뷰의 감정은 무엇인가요?

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %%
prompt = f"""
다음 제품 리뷰의 감정은 무엇인가요?
다음 제품 리뷰의 감정을 한 단어로 나타내주세요. "긍정적" 또는 "부정적" 중 하나로 답하세요.

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %% [markdown]
# ## 감정 유형 식별

# %%
prompt = f"""
다음 리뷰 작성자가 표현한 감정 유형을 나열하세요. \
목록에는 다섯 개 이상의 항목을 포함하지 마세요. \
소문자 단어로 된 목록 형식으로 답하세요. 각 항목은 쉼표로 구분합니다.

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %% [markdown]
# ## 분노 식별

# %%
prompt = f"""
다음 리뷰 작성자가 분노를 표현하고 있는지 여부를 판단하세요. \
리뷰는 삼중 역따옴표로 구분됩니다. \
답변은 "예" 또는 "아니요"로 제공하세요.

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %% [markdown]
# ## 고객 리뷰에서 제품 및 회사 이름 추출

# %%
prompt = f"""
다음 리뷰 텍스트에서 다음 항목을 식별하세요:
- 리뷰어가 구매한 상품
- 해당 상품을 제조한 회사

리뷰는 삼중 역따옴표로 구분됩니다. \
"Item"과 "Brand"가 키인 JSON 객체 형식으로 \
응답을 작성하세요. 정보가 없는 경우 "unknown"을 \
값으로 사용하세요.
응답을 최대한 간결하게 작성하세요.

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %% [markdown]
# ## 여러 작업 동시에 수행

# %%
prompt = f"""
다음 리뷰 텍스트에서 다음 항목을 식별하세요:
- 감정 (긍정적 또는 부정적)
- 리뷰어가 분노를 표현하고 있는지 여부 (참 또는 거짓)
- 리뷰어가 구매한 상품
- 해당 상품을 제조한 회사

리뷰는 삼중 역따옴표로 구분됩니다. \
"Sentiment", "Anger", "Item" 및 "Brand"가 키인 \
JSON 객체 형식으로 응답을 작성하세요. 정보가 없는 경우 \
값으로 "unknown"을 사용하세요.
응답을 최대한 간결하게 작성하세요.
Anger 값을 부울(boolean) 형식으로 포맷하세요.

리뷰 텍스트: '''{lamp_review}'''
"""
response = get_completion(prompt)
print(response)

# %% [markdown]
# ## 아까 만들었던 리뷰들을 긍정/부정에 기반하여 5점 만점의 점수로 만들어 변환하여 응답하는 프롬프트를 작성해 보세요.

# %%
reviews = [review_1, review_2, review_3, review_4]
# YOUR PROMPT HERE.

# %% [markdown]
# ## 주제 추론

# %%
story = """
정부가 최근 실시한 조사에서 공공부문 직원들에게 부서에서의 만족도를 평가하도록 했습니다.
결과에서는 NASA가 95%의 만족도 평가로 가장 인기 있는 부서임을 밝혀냈습니다.

NASA 직원인 존 스미스는 결과에 대해 다음과 같이 언급하며 말했습니다.
"NASA가 선두에 올 줄은 놀랍지 않아요. 그곳은 놀라운 사람들과 놀라운 기회가 있는
일하기 좋은 장소입니다. 이런 혁신적인 조직의 일원으로 자랑스러워요."

결과는 또한 NASA 경영진에 의해 환영받았습니다. 톰 존슨 이사는 다음과 같이 말했습니다.
"우리 직원들이 NASA에서의 업무에 만족하고 있다는 것을 들어서 기쁩니다.
우리는 우리의 목표를 달성하기 위해 헌신적으로 일하는 재능 있는 팀을 보유하고 있으며,
그들의 노력이 빛을 발하는 것을 보는 것은 환상적입니다."

조사는 또한 사회보장청이 가장 낮은 만족도 평가를 받았음을 밝혀냈는데,
직원의 45%만이 자신의 직장에 만족한다고 했습니다.
정부는 조사에서 직원들이 제기한 우려사항을 해결하고 모든 부서에서 직장 만족도를
향상시키기 위해 노력하기로 약속했습니다.
"""

# %% [markdown]
# ## 5개 주제 추론

# %%
prompt = f"""
다음 텍스트에서 논의되고 있는 다섯 가지 주제를 결정하세요.
텍스트는 삼중 역따옴표로 구분됩니다.

각 항목을 한 단어 또는 두 단어로 작성하세요.

답변을 쉼표로 구분된 항목 목록 형식으로 작성하세요.

텍스트 샘플: '''{story}'''
"""
response = get_completion(prompt)
print(response)

# %%
response.split(sep=',')

# %% [markdown]
# ## 특정 주제에 대한 뉴스 알림 생성

# %%
topic_list = [
    "nasa", "지방 정부", "공학",
    "직원 만족도", "연방 정부"
]
prompt = f"""
다음 목록의 각 항목이 다음 텍스트에서 주제인지 여부를 결정하세요.
텍스트는 삼중 역따옴표로 구분됩니다.

각 주제에 대해 0 또는 1로 답하세요.

주제 목록: {", ".join(topic_list)}

텍스트 샘플: '''{story}'''
"""
response = get_completion(prompt)
print(response)

# %%
topic_dict = {i.split(': ')[0]: int(i.split(': ')[1]) for i in response.split(sep='\n')}
if topic_dict['nasa'] == 1:
    print("ALERT: New NASA story!")
